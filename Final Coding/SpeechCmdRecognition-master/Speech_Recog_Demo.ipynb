# %% [markdown]
# # Speech Command Recognition
#
# This notebook presents an attention model for speech command recognotion. We use Google Speech Commands Dataset to test the Keras generator for sound files and the proposed RNN attention model.
#
#
# ## Download files and load information
#
# Dynamically load speech data from the disk to allow handling big datasets.
#
# First step: download Google Speech Command Dataset and convert all WAV files to numpy arrays for faster load (about 10x faster than loading raw WAV).

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16182711163440125319
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 4181524480
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 4418427038020206266
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]

# %%
#%load_ext autoreload
#%autoreload 2

import librosa
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  

import SpeechDownloader
import SpeechGenerator
import SpeechModels

# %%
# Download and prepare all data
gscInfo, nCategs = SpeechDownloader.PrepareGoogleSpeechCmd(version=2, task='custom')
# Out:
# Google Speech commands dataset version 2 already exists. Skipping download.
# Converting test set WAVs to numpy files
# 0it [00:00, ?it/s]
# Converting training set WAVs to numpy files
# 0it [00:00, ?it/s]
# Done preparing Google Speech commands dataset version 2

# %% [markdown]
# We should have 4 datasets, each with file names 'files' and their categories 'labels' in a dict.

# %%
print(gscInfo.keys())
print(gscInfo['train'].keys())
print(len(gscInfo['train']['files']))
print(nCategs)
# Out:
# dict_keys(['train', 'test', 'val', 'testREAL'])
# dict_keys(['files', 'labels'])
# 84849
# 36

# %% [markdown]
# # Speech Data Generator
#
# Use Keras to create a generator that reads files on the fly.

# %%
sr = 16000 #we know this one for google audios
iLen = 16000
trainGen = SpeechGenerator.SpeechGen(gscInfo['train']['files'], gscInfo['train']['labels'], shuffle=True)
# handle the fact that number of samples in validation may not be multiple of batch_size with shuffle=True
valGen   = SpeechGenerator.SpeechGen(gscInfo['val']['files'], gscInfo['val']['labels'], shuffle=True)

# use batch_size = total number of files to read all test files at once
testGen  = SpeechGenerator.SpeechGen(gscInfo['test']['files'], gscInfo['test']['labels'], shuffle=False, batch_size=len(gscInfo['test']['files']))
testRGen = SpeechGenerator.SpeechGen(gscInfo['testREAL']['files'], gscInfo['testREAL']['labels'], shuffle=False, batch_size=len(gscInfo['testREAL']['files']))
valGen.__len__()
# Out:
# 311

# %%
audios, classes = valGen.__getitem__(5)
classes
# Out:
# array([ 4,  6, 16, 10, 14, 25, 19, 14, 10, 16, 12, 19, 17, 14, 25, 16, 33,
#        29,  4,  4, 12, 17,  7,  2, 18, 20, 31,  2,  2, 18, 32, 10])

# %%
# librosa.output.write_wav('file.wav', audios[4], sr, norm=False)
plt.plot(audios[4])

# %%
from tensorflow.keras.models import Sequential
from kapre.time_frequency import Melspectrogram, Spectrogram
from kapre.utils import Normalization2D

melspecModel = Sequential()

melspecModel.add(Melspectrogram(n_dft=1024, n_hop=128, input_shape=(1, iLen),
                         padding='same', sr=sr, n_mels=80,
                         fmin=40.0, fmax=sr/2, power_melgram=1.0,
                         return_decibel_melgram=True, trainable_fb=False,
                         trainable_kernel=False,
                         name='mel_stft') )

melspecModel.add(Normalization2D(int_axis=0))

melspecModel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mel_stft (Melspectrogram)   (None, 80, 125, 1)        1091664
#
#  normalization2d (Normalizat  (None, 80, 125, 1)       0
#  ion2D)
#
# =================================================================
# Total params: 1,091,664
# Trainable params: 1,091,664
# Non-trainable params: 0
# _________________________________________________________________

# %%
melspec = melspecModel.predict( audios.reshape((-1,1,iLen)) )
melspec.shape
# Out:
# (32, 80, 125, 1)

# %%
plt.figure(figsize=(17,6))
plt.pcolormesh(melspec[9,:,:,0])

plt.title('Spectrogram visualization')
plt.ylabel('Frequency')
plt.xlabel('Time')

plt.show()

# %%
# Check if mel spectrogram matches the one computed with librosa
librosa_melspec = librosa.feature.melspectrogram(y=audios[9], sr=sr, n_fft=1024,
                                                 hop_length=128, power=1.0, #window='hann',
                                                 n_mels=80, fmin=40.0, fmax=sr/2)
S_dB = librosa.power_to_db(librosa_melspec, ref=np.max)

# %%
plt.figure(figsize=(17,6))
plt.pcolormesh(S_dB)

plt.title('Spectrogram visualization - librosa')
plt.ylabel('Frequency')
plt.xlabel('Time')

plt.show()

# %%
# plt.hist(melspec.flatten(), bins=100)

# %% [markdown]
# # Models
#
# Create Keras models to see if the generators are working properly

# %%
from tensorflow.keras.models import Model, load_model

from kapre.time_frequency import Melspectrogram, Spectrogram

# %%
#self-attention LSTM
#nCategs=36
#sr=16000
#iLen=16000
#from keras import layers as L

model = SpeechModels.AttRNNSpeechModel(nCategs, samplingrate = sr, inputLength = None)#, rnn_func=L.LSTM)

model.compile(optimizer='adam', loss=['sparse_categorical_crossentropy'], metrics=['sparse_categorical_accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, None)]       0           []
#
#  reshape (Reshape)              (None, 1, None)      0           ['input[0][0]']
#
#  mel_stft (Melspectrogram)      (None, 80, None, 1)  1091664     ['reshape[0][0]']
#
#  mel_stft_norm (Normalization2D  (None, 80, None, 1)  0          ['mel_stft[0][0]']
#  )
#
#  permute (Permute)              (None, None, 80, 1)  0           ['mel_stft_norm[0][0]']
#
#  conv2d (Conv2D)                (None, None, 80, 10  60          ['permute[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, None, 80, 10  40         ['conv2d[0][0]']
#  alization)                     )
#
#  conv2d_1 (Conv2D)              (None, None, 80, 1)  51          ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, None, 80, 1)  4          ['conv2d_1[0][0]']
#  rmalization)
#
#  squeeze_last_dim (Lambda)      (None, None, 80)     0           ['batch_normalization_1[0][0]']
#
#  bidirectional (Bidirectional)  (None, None, 128)    74240       ['squeeze_last_dim[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, None, 128)   98816       ['bidirectional[0][0]']
#  )
#
#  lambda (Lambda)                (None, 128)          0           ['bidirectional_1[0][0]']
#
#  dense (Dense)                  (None, 128)          16512       ['lambda[0][0]']
#
#  dot (Dot)                      (None, None)         0           ['dense[0][0]',
#                                                                   'bidirectional_1[0][0]']
#
#  attSoftmax (Softmax)           (None, None)         0           ['dot[0][0]']
#
#  dot_1 (Dot)                    (None, 128)          0           ['attSoftmax[0][0]',
#                                                                   'bidirectional_1[0][0]']
#
#  dense_1 (Dense)                (None, 64)           8256        ['dot_1[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  output (Dense)                 (None, 36)           1188        ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 1,292,911
# Trainable params: 201,225
# Non-trainable params: 1,091,686
# __________________________________________________________________________________________________

# %%
# model.load_weights('model-attRNN.h5')

# %%
import math
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
def step_decay(epoch):
    initial_lrate = 0.001
    drop = 0.4
    epochs_drop = 15.0
    lrate = initial_lrate * math.pow(drop,  
            math.floor((1+epoch)/epochs_drop))
    
    if (lrate < 4e-5):
        lrate = 4e-5
      
    print('Changing learning rate to {}'.format(lrate))
    return lrate
lrate = LearningRateScheduler(step_decay)

# %%
earlystopper = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=10,
                             verbose=1, restore_best_weights=True)
checkpointer = ModelCheckpoint('model-attRNN.h5', monitor='val_sparse_categorical_accuracy', verbose=1, save_best_only=True)

results = model.fit(trainGen, validation_data=valGen, epochs=100, use_multiprocessing=False, workers=4, verbose=2,
                    callbacks=[earlystopper, checkpointer, lrate])

model.save('model-attRNN.h5')
# Out:
# Changing learning rate to 0.001
# Epoch 1/100
#
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.88173, saving model to model-attRNN.h5
# 2651/2651 - 267s - loss: 0.8138 - sparse_categorical_accuracy: 0.7661 - val_loss: 0.4117 - val_sparse_categorical_accuracy: 0.8817 - lr: 0.0010 - 267s/epoch - 101ms/step
# Changing learning rate to 0.001
# Epoch 2/100
#
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.88173 to 0.90916, saving model to model-attRNN.h5
# 2651/2651 - 128s - loss: 0.3704 - sparse_categorical_accuracy: 0.8919 - val_loss: 0.3109 - val_sparse_categorical_accuracy: 0.9092 - lr: 0.0010 - 128s/epoch - 48ms/step
# Changing learning rate to 0.001
# Epoch 3/100
#
# Epoch 00003: val_sparse_categorical_accuracy improved from 0.90916 to 0.92142, saving model to model-attRNN.h5
# 2651/2651 - 153s - loss: 0.2817 - sparse_categorical_accuracy: 0.9158 - val_loss: 0.2673 - val_sparse_categorical_accuracy: 0.9214 - lr: 0.0010 - 153s/epoch - 58ms/step
# Changing learning rate to 0.001
# Epoch 4/100
#
# Epoch 00004: val_sparse_categorical_accuracy improved from 0.92142 to 0.92785, saving model to model-attRNN.h5
# 2651/2651 - 133s - loss: 0.2309 - sparse_categorical_accuracy: 0.9311 - val_loss: 0.2649 - val_sparse_categorical_accuracy: 0.9279 - lr: 0.0010 - 133s/epoch - 50ms/step
# Changing learning rate to 0.001
# Epoch 5/100
#
# Epoch 00005: val_sparse_categorical_accuracy did not improve from 0.92785
# 2651/2651 - 149s - loss: 0.2011 - sparse_categorical_accuracy: 0.9401 - val_loss: 0.2638 - val_sparse_categorical_accuracy: 0.9246 - lr: 0.0010 - 149s/epoch - 56ms/step
# Changing learning rate to 0.001
# Epoch 6/100
#
# Epoch 00006: val_sparse_categorical_accuracy did not improve from 0.92785
# 2651/2651 - 131s - loss: 0.1712 - sparse_categorical_accuracy: 0.9483 - val_loss: 0.2563 - val_sparse_categorical_accuracy: 0.9277 - lr: 0.0010 - 131s/epoch - 49ms/step
# Changing learning rate to 0.001
# Epoch 7/100
#
# Epoch 00007: val_sparse_categorical_accuracy improved from 0.92785 to 0.93348, saving model to model-attRNN.h5
# 2651/2651 - 150s - loss: 0.1557 - sparse_categorical_accuracy: 0.9524 - val_loss: 0.2375 - val_sparse_categorical_accuracy: 0.9335 - lr: 0.0010 - 150s/epoch - 56ms/step
# Changing learning rate to 0.001
# Epoch 8/100
#
# Epoch 00008: val_sparse_categorical_accuracy improved from 0.93348 to 0.93469, saving model to model-attRNN.h5
# 2651/2651 - 130s - loss: 0.1381 - sparse_categorical_accuracy: 0.9576 - val_loss: 0.2442 - val_sparse_categorical_accuracy: 0.9347 - lr: 0.0010 - 130s/epoch - 49ms/step
# Changing learning rate to 0.001
# Epoch 9/100
#
# Epoch 00009: val_sparse_categorical_accuracy improved from 0.93469 to 0.93690, saving model to model-attRNN.h5
# 2651/2651 - 151s - loss: 0.1245 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.2410 - val_sparse_categorical_accuracy: 0.9369 - lr: 0.0010 - 151s/epoch - 57ms/step
# Changing learning rate to 0.001
# Epoch 10/100
#
# Epoch 00010: val_sparse_categorical_accuracy improved from 0.93690 to 0.94433, saving model to model-attRNN.h5
# 2651/2651 - 132s - loss: 0.1180 - sparse_categorical_accuracy: 0.9632 - val_loss: 0.2265 - val_sparse_categorical_accuracy: 0.9443 - lr: 0.0010 - 132s/epoch - 50ms/step
# Changing learning rate to 0.001
# Epoch 11/100
#
# Epoch 00011: val_sparse_categorical_accuracy did not improve from 0.94433
# 2651/2651 - 148s - loss: 0.1037 - sparse_categorical_accuracy: 0.9680 - val_loss: 0.2725 - val_sparse_categorical_accuracy: 0.9320 - lr: 0.0010 - 148s/epoch - 56ms/step
# Changing learning rate to 0.001
# Epoch 12/100
#
# Epoch 00012: val_sparse_categorical_accuracy did not improve from 0.94433
# 2651/2651 - 135s - loss: 0.0981 - sparse_categorical_accuracy: 0.9699 - val_loss: 0.2390 - val_sparse_categorical_accuracy: 0.9430 - lr: 0.0010 - 135s/epoch - 51ms/step
# Changing learning rate to 0.001
# Epoch 13/100
#
# Epoch 00013: val_sparse_categorical_accuracy did not improve from 0.94433
# 2651/2651 - 126s - loss: 0.0925 - sparse_categorical_accuracy: 0.9712 - val_loss: 0.2528 - val_sparse_categorical_accuracy: 0.9402 - lr: 0.0010 - 126s/epoch - 47ms/step
# Changing learning rate to 0.001
# Epoch 14/100
#
# Epoch 00014: val_sparse_categorical_accuracy did not improve from 0.94433
# 2651/2651 - 128s - loss: 0.0876 - sparse_categorical_accuracy: 0.9731 - val_loss: 0.2663 - val_sparse_categorical_accuracy: 0.9389 - lr: 0.0010 - 128s/epoch - 48ms/step
# Changing learning rate to 0.0004
# Epoch 15/100
#
# Epoch 00015: val_sparse_categorical_accuracy improved from 0.94433 to 0.94574, saving model to model-attRNN.h5
# 2651/2651 - 123s - loss: 0.0514 - sparse_categorical_accuracy: 0.9848 - val_loss: 0.2555 - val_sparse_categorical_accuracy: 0.9457 - lr: 4.0000e-04 - 123s/epoch - 46ms/step
# Changing learning rate to 0.0004
# Epoch 16/100
#
# Epoch 00016: val_sparse_categorical_accuracy improved from 0.94574 to 0.94614, saving model to model-attRNN.h5
# 2651/2651 - 121s - loss: 0.0406 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.2869 - val_sparse_categorical_accuracy: 0.9461 - lr: 4.0000e-04 - 121s/epoch - 46ms/step
# Changing learning rate to 0.0004
# Epoch 17/100
#
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.94614
# 2651/2651 - 122s - loss: 0.0382 - sparse_categorical_accuracy: 0.9892 - val_loss: 0.3000 - val_sparse_categorical_accuracy: 0.9454 - lr: 4.0000e-04 - 122s/epoch - 46ms/step
# Changing learning rate to 0.0004
# Epoch 18/100
#
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.94614
# 2651/2651 - 121s - loss: 0.0339 - sparse_categorical_accuracy: 0.9905 - val_loss: 0.3110 - val_sparse_categorical_accuracy: 0.9445 - lr: 4.0000e-04 - 121s/epoch - 45ms/step
# Changing learning rate to 0.0004
# Epoch 19/100
#
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.94614
# 2651/2651 - 118s - loss: 0.0324 - sparse_categorical_accuracy: 0.9907 - val_loss: 0.3045 - val_sparse_categorical_accuracy: 0.9460 - lr: 4.0000e-04 - 118s/epoch - 44ms/step
# Changing learning rate to 0.0004
# Epoch 20/100
#
# Epoch 00020: val_sparse_categorical_accuracy did not improve from 0.94614
# 2651/2651 - 116s - loss: 0.0282 - sparse_categorical_accuracy: 0.9920 - val_loss: 0.3556 - val_sparse_categorical_accuracy: 0.9430 - lr: 4.0000e-04 - 116s/epoch - 44ms/step
# Changing learning rate to 0.0004
# Epoch 21/100
#
# Epoch 00021: val_sparse_categorical_accuracy did not improve from 0.94614
# 2651/2651 - 116s - loss: 0.0283 - sparse_categorical_accuracy: 0.9920 - val_loss: 0.3431 - val_sparse_categorical_accuracy: 0.9450 - lr: 4.0000e-04 - 116s/epoch - 44ms/step
# Changing learning rate to 0.0004
# Epoch 22/100
#
# Epoch 00022: val_sparse_categorical_accuracy did not improve from 0.94614
# 2651/2651 - 116s - loss: 0.0253 - sparse_categorical_accuracy: 0.9931 - val_loss: 0.3692 - val_sparse_categorical_accuracy: 0.9439 - lr: 4.0000e-04 - 116s/epoch - 44ms/step
# Changing learning rate to 0.0004
# Epoch 23/100
#
# Epoch 00023: val_sparse_categorical_accuracy did not improve from 0.94614
# 2651/2651 - 116s - loss: 0.0239 - sparse_categorical_accuracy: 0.9931 - val_loss: 0.3790 - val_sparse_categorical_accuracy: 0.9440 - lr: 4.0000e-04 - 116s/epoch - 44ms/step
# Changing learning rate to 0.0004
# Epoch 24/100
#
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.94614
# 2651/2651 - 115s - loss: 0.0220 - sparse_categorical_accuracy: 0.9936 - val_loss: 0.3772 - val_sparse_categorical_accuracy: 0.9446 - lr: 4.0000e-04 - 115s/epoch - 44ms/step
# Changing learning rate to 0.0004
# Epoch 25/100
#
# Epoch 00025: val_sparse_categorical_accuracy did not improve from 0.94614
# 2651/2651 - 116s - loss: 0.0207 - sparse_categorical_accuracy: 0.9941 - val_loss: 0.3839 - val_sparse_categorical_accuracy: 0.9450 - lr: 4.0000e-04 - 116s/epoch - 44ms/step
# Changing learning rate to 0.0004
# Epoch 26/100
# Restoring model weights from the end of the best epoch: 16.
#
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.94614
# 2651/2651 - 116s - loss: 0.0209 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.4064 - val_sparse_categorical_accuracy: 0.9436 - lr: 4.0000e-04 - 116s/epoch - 44ms/step
# Epoch 00026: early stopping

# %%
# summarize history for categorical accuracy
plt.plot(results.history['sparse_categorical_accuracy'])
plt.plot(results.history['val_sparse_categorical_accuracy'])
plt.title('Categorical accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# results.history

# %%
from tensorflow.keras.models import Sequential
from kapre.time_frequency import Melspectrogram, Spectrogram
from kapre.utils import Normalization2D

# %%
# load best model according to cross-validation - model-attRNN
model = load_model('model-attRNN.h5', custom_objects={'Melspectrogram': Melspectrogram, 'Normalization2D': Normalization2D })
#model.load_weights('model-attRNN.h5')

# %%
#read all test data
x_test, y_test = testGen.__getitem__(0)

# %%
valEval = model.evaluate(valGen, use_multiprocessing=False, workers=4,verbose=0)
trainEval = model.evaluate(trainGen, use_multiprocessing=False, workers=4,verbose=0)
testEval = model.evaluate(x_test, y_test, verbose=0)
print('Evaluation scores: \nMetrics: {} \nTrain: {} \nValidation: {} \nTest: {}'.format(model.metrics_names, trainEval, valEval, testEval) )
# Out:
# Evaluation scores:
# Metrics: ['loss', 'sparse_categorical_accuracy']
# Train: [0.0355549193918705, 0.9899094700813293]
# Validation: [0.2870999872684479, 0.9456390738487244]
# Test: [0.28600552678108215, 0.9420263767242432]

# %%
kaggle12cmd = False
if kaggle12cmd:
    #only for the Kaggle competition, 12-cmd
    x_testR, y_testR = testRGen.__getitem__(0)
    testREval = model.evaluate(x_testR, y_testR, verbose=1)
    print(testREval)
    testREval = model.evaluate(testRGen, use_multiprocessing=True, workers=4,verbose=1)
    print(testREval)

# %% [markdown]
# ## Evaluation and Attention Plots

# %%
attSpeechModel = Model(inputs=model.input,
                                 outputs=[model.get_layer('output').output, 
                                          model.get_layer('attSoftmax').output,
                                          model.get_layer('mel_stft').output])

# %%
audios, classes = valGen.__getitem__(3)
classes
# Out:
# array([21, 35, 31,  3, 11, 14, 17, 12, 28, 32,  4,  5,  4, 24, 15, 33, 16,
#         4, 25, 12, 20, 32, 14, 28, 31, 19, 10, 11,  4, 12, 17, 18])

# %%
#8 - on, 13 - one, 7 - right
idAudio = 8
classes[idAudio]
# Out:
# 28

# %%
outs, attW, specs = attSpeechModel.predict(audios)

# %%
np.argmax(outs,axis=1)
# Out:
# array([21, 35, 26,  3, 11, 14, 17, 12, 28, 32,  4,  5,  4, 24,  6, 33, 16,
#         4, 25, 12, 20, 32, 14, 28, 31, 19, 10, 11,  4, 12, 17, 18],
#       dtype=int64)

# %%
specs.shape
# Out:
# (32, 80, 125, 1)

# %%
imgHeight = 2

plt.figure(figsize=(17,imgHeight))
plt.title('Raw waveform', fontsize=30)
plt.ylabel('Amplitude', fontsize=30)
plt.xlabel('Sample index', fontsize=30)
plt.plot(audios[idAudio])
plt.savefig('picrawWave.png', dpi = 400)
plt.show()

plt.figure(figsize=(17,imgHeight))
plt.title('Attention weights (log)', fontsize=30)
plt.ylabel('Log of attention weight', fontsize=30)
plt.xlabel('Mel-spectrogram index', fontsize=30)
plt.plot(np.log(attW[idAudio]))
plt.savefig('picAttention.png', dpi = 400)
plt.show()


plt.figure(figsize=(17,imgHeight*2))
plt.pcolormesh(specs[idAudio,:,:,0])

plt.title('Spectrogram visualization', fontsize=30)
plt.ylabel('Frequency', fontsize=30)
plt.xlabel('Time', fontsize=30)
plt.savefig('picmelSpec.png', dpi = 400)

plt.show()

# %%
x_test[0]
# Out:
# array([ 3.05175781e-05,  3.05175781e-05,  1.52587891e-04, ...,
#        -7.32421875e-04, -4.48608398e-03,  4.63867188e-03])

# %%
y_pred = model.predict(x_test, verbose=1)
# Out:
# 344/344 [==============================] - 8s 20ms/step

# %%
print(np.argmax(y_pred,1))
# Out:
# [ 7  7  7 ... 30 16 16]

# %%
print(len(np.argmax(y_pred,1)))
# Out:
# 11005

# %%
from sklearn.metrics import confusion_matrix
import audioUtils
cm = confusion_matrix(y_test, np.argmax(y_pred,1))

# %%
#set(y_test)

# %%
classes=["yes","no","up","down","left","right","on","off","stop","go","backward","forward"]

# %%
#35word, v2
classes = ['nine', 'yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go',
           'zero', 'one', 'two', 'three', 'four', 'five', 'six', 
           'seven',  'eight', 'backward', 'bed', 'bird', 'cat', 'dog',
           'follow', 'forward', 'happy', 'house', 'learn', 'marvin', 'sheila', 'tree',
           'visual', 'wow']

# %%
#35word, v1
#classes=['nine', 'yes',  'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go',
#         'zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven',  'eight', 
#         'bed', 'bird', 'cat', 'dog', 'happy', 'house', 
#         'marvin', 'sheila', 'tree', 'wow']

# %%
#20cmd
#classes=['unknown', 'nine', 'yes',  'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go',
#         'zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven',  'eight']

# %%
audioUtils.plot_confusion_matrix(cm, classes, normalize=False)
# Out:
# Confusion matrix, without normalization

# %%
import pandas as pd
import kapre
[tf.__version__, kapre.__version__, pd.__version__, librosa.__version__]
# Out:
# ['2.7.0', '0.2.0', '1.4.0', '0.8.1']

# %% [markdown]
# # Save model to .pb

# %%
#model = SpeechModels.AttRNNSpeechModel(nCategs, samplingrate = sr, inputLength = None)#, rnn_func=L.LSTM)
#model.load_weights('model-attRNN.h5')

model = load_model('model-attRNN.h5', custom_objects={'Melspectrogram': Melspectrogram, 'Normalization2D': Normalization2D })

# %%
tf.saved_model.save(model, "attRNNModel/1/")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_13_layer_call_fn, lstm_cell_13_layer_call_and_return_conditional_losses, lstm_cell_14_layer_call_fn, lstm_cell_14_layer_call_and_return_conditional_losses, lstm_cell_16_layer_call_fn while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: attRNNModel/1/assets
# INFO:tensorflow:Assets written to: attRNNModel/1/assets

# %%
import os
os.listdir('attRNNModel/1/')
# Out:
# ['assets', 'saved_model.pb', 'variables']

# %%
# if using tensorflow 1.x

# %%
# save model to pb ====================
def freeze_session(session, keep_var_names=None, output_names=None, clear_devices=True):
    """
    Freezes the state of a session into a pruned computation graph.
    Creates a new computation graph where variable nodes are replaced by
    constants taking their current value in the session. The new graph will be
    pruned so subgraphs that are not necessary to compute the requested
    outputs are removed.
    @param session The TensorFlow session to be frozen.
    @param keep_var_names A list of variable names that should not be frozen,
                          or None to freeze all the variables in the graph.
    @param output_names Names of the relevant graph outputs.
    @param clear_devices Remove the device directives from the graph for better portability.
    @return The frozen graph definition.
    """
    from tensorflow.python.framework.graph_util import convert_variables_to_constants
    graph = session.graph
    with graph.as_default():
        freeze_var_names = list(set(v.op.name for v in tf.global_variables()).difference(keep_var_names or []))
        output_names = output_names or []
        output_names += [v.op.name for v in tf.global_variables()]
        input_graph_def = graph.as_graph_def()
        if clear_devices:
            for node in input_graph_def.node:
                node.device = ""
        frozen_graph = convert_variables_to_constants(session, input_graph_def,
                                                      output_names, freeze_var_names)
        return frozen_graph

# %%
wkdir = ''
pb_filename = 'attRNN.pb'

# save keras model as tf pb files ===============
sess = tf.compat.v1.keras.backend.get_session()

#frozen_graph = freeze_session(sess,
#                              output_names=[out.op.name for out in model.outputs])
#tf.train.write_graph(frozen_graph, wkdir, pb_filename, as_text=False)
# Out:
# WARNING:tensorflow:From C:\Users\panur\AppData\Local\Temp/ipykernel_16000/2983713989.py:5: The name tf.keras.backend.get_session is deprecated. Please use tf.compat.v1.keras.backend.get_session instead.
# WARNING:tensorflow:From C:\Users\panur\AppData\Local\Temp/ipykernel_16000/2983713989.py:5: The name tf.keras.backend.get_session is deprecated. Please use tf.compat.v1.keras.backend.get_session instead.
